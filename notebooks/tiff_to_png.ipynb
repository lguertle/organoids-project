# %%
from PIL import Image
import os
from importlib import reload
import utility
reload(utility)
from utility import get_hard_disk_path

# Define the directories
initial_path = get_hard_disk_path("Laure")
print(initial_path)
directories = ["empty", "j2", "j8"]

# Create a function to convert TIFF to PNG
def convert_tiff_to_png(directory, initial_path):
    # Check if the directory exists
    directory = os.path.join(initial_path, directory)
    if not os.path.exists(directory):
        print(f"Directory '{directory}' not found.")
        return

    # Make a new directory to store the PNG files
    png_directory = f"{directory}_png"
    os.makedirs(png_directory, exist_ok=True)

    # Convert each TIFF file in the directory to PNG
    for filename in os.listdir(directory):
        if filename.endswith(".tiff"):
            with Image.open(os.path.join(directory, filename)) as img:
                # Change the file extension to .png
                png_filename = os.path.splitext(filename)[0] + ".png"
                # Save the image in PNG format
                img.save(os.path.join(png_directory, png_filename))
            print(f"Converted {filename} to PNG format.")

# Convert the images in each directory
for dir in directories:
    convert_tiff_to_png(dir, initial_path)
# Out:
# Successfully loaded data from E:/mouse_organoids_laure/
# E:/mouse_organoids_laure/
# Converted 2023042120230421lgms3orgamgtlp0j8top011_s3_a2_p1_t0-48_bf.tiff to PNG format.
# Converted 2023042120230421lgms3orgamgtlp0j8top011_s3_a2_p5_t0-48_bf.tiff to PNG format.
# Converted 2023042120230421lgms3orgamgtlp0j8top011_s3_a2_p6_t0-48_bf.tiff to PNG format.
# Converted 2023042120230421lgms4orgamgp0j2_s3_a1_p5_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms4orgamgp0j2_s3_a1_p6_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms2orgamgp0j8_s6_a3_p6_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms2orgamgp0j8_s6_a3_p7_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms2orgamgp0j8_s6_a3_p8_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms2orgamgp0j8_s6_a3_p9_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms2orgamgp0j8_s6_a3_p10_t0_bf.tiff to PNG format.
# Converted 2023042120230421lgms2orgamgp0j8_s6_a3_p11_t0_bf.tiff to PNG format.
# ...

# %%
# !python --version
# Out:
# Python 3.11.5

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20
# Out:
# ERROR: Ignored the following versions that require a different python version: 8.0.10 Requires-Python >=3.7,<=3.11; 8.0.11 Requires-Python >=3.7,<=3.11; 8.0.12 Requires-Python >=3.7,<=3.11; 8.0.13 Requires-Python >=3.7,<=3.11; 8.0.14 Requires-Python >=3.7,<=3.11; 8.0.15 Requires-Python >=3.7,<=3.11; 8.0.16 Requires-Python >=3.7,<=3.11; 8.0.17 Requires-Python >=3.7,<=3.11; 8.0.18 Requires-Python >=3.7,<=3.11; 8.0.19 Requires-Python >=3.7,<=3.11; 8.0.20 Requires-Python >=3.7,<=3.11; 8.0.21 Requires-Python >=3.7,<=3.11; 8.0.22 Requires-Python >=3.7,<=3.11; 8.0.23 Requires-Python >=3.7,<=3.11; 8.0.24 Requires-Python >=3.7,<=3.11; 8.0.25 Requires-Python >=3.7,<=3.11; 8.0.26 Requires-Python >=3.7,<=3.11; 8.0.27 Requires-Python >=3.7,<=3.11; 8.0.28 Requires-Python >=3.7,<=3.11; 8.0.29 Requires-Python >=3.7,<=3.11; 8.0.30 Requires-Python >=3.7,<=3.11; 8.0.31 Requires-Python >=3.7,<=3.11; 8.0.32 Requires-Python >=3.7,<=3.11; 8.0.33 Requires-Python >=3.7,<=3.11; 8.0.34 Requires-Python >=3.7,<=
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\lguertle\organoids-project\notebooks\tiff_to_png.ipynb Cell 2 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/lguertle/organoids-project/notebooks/tiff_to_png.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> from IPython import display
#       <a href='vscode-notebook-cell:/c%3A/Users/lguertle/organoids-project/notebooks/tiff_to_png.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> display.clear_output()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lguertle/organoids-project/notebooks/tiff_to_png.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> import ultralytics
#       <a href='vscode-notebook-cell:/c%3A/Users/lguertle/organoids-project/notebooks/tiff_to_png.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> ultralytics.checks()
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
import os
HOME = os.getcwd()
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="A7uPcSnDqx6mo8bLDs3m")
project = rf.workspace("epfl-vptwb").project("organoids-classification")
dataset = project.version(1).download("yolov8")
# Out:
# [WinError 2] The system cannot find the file specified: 'c:\\Users\\lguertle\\organoids-project\\notebooks/datasets'
# c:\Users\lguertle\organoids-project\notebooks
# The syntax of the command is incorrect.
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to organoids-classification-1 in yolov8:: 100%|██████████| 86/86 [00:00<00:00, 1685.86it/s]

# %%
import os
HOME = os.getcwd()
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={"organoids-classification-1"}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# c:\Users\lguertle\organoids-project\notebooks
# 'yolo' is not recognized as an internal or external command,
# operable program or batch file.
