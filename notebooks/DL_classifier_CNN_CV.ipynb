# %% [markdown]
# # Uploading libraries

# %%
# Fundamental libraries

import os
import random
import time
import copy

# Working libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import wandb
from torch.autograd import Variable
from sklearn.metrics import classification_report
import torch.utils.data as data
import torchvision
from torchvision import transforms
from PIL import Image
from transformers import AutoImageProcessor, ViTImageProcessor, ViTForImageClassification, ViTConfig, ResNetForImageClassification, ResNetConfig, BeitForImageClassification, BeitConfig, BeitImageProcessor, AutoFeatureExtractor
import torchvision.transforms.functional as TF
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models
import torch.optim as optim
from torch.optim import lr_scheduler
from sklearn.metrics import f1_score
from importlib import reload
import utility
reload(utility)
from utility import load_data, plot_confusion_matrix, plot_average_f1_scores, train_model, get_classification_details, get_hard_disk_path, show_samples, plot_features_importance, visualize_correlation, get_shap

# Evaluation
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Model Recommendations
# VGG-16: Despite being relatively deep, VGG-16 can still be effective on smaller datasets, especially when used with transfer learning. Its simplicity and well-understood architecture make it a good starting point.
#
# ResNet-50: ResNet models, especially the shallower ones like ResNet-50, are known for their ability to avoid overfitting through the use of residual connections. This can be beneficial for learning from small datasets.
#
# MobileNet: Designed for mobile and resource-constrained environments, MobileNets are lightweight and efficient, which can be advantageous when training data is limited.
#
# SqueezeNet: This network achieves AlexNet-level accuracy with significantly fewer parameters. Its compact architecture makes it suitable for small datasets and limited computational resources.

# %% [markdown]
# # FILE PATHS on local environment

# %% [markdown]
# #### Each folder path represent class (label) :
#
# **Folder name - calss name : description**
#
# 0 - 0 class : dead
#
# 1 - 1 class : empty
#
# 2 - 2 class : keep0
#
# 3 - 3 class : keep1
#
# 4 - 4 class : keep2
#
# 5 - 5 class : reseed0
#
# 6 - 6 class : reseed1
#
# 7 -  7 class : split

# %%
# paths for data upload
FILE_PATH = get_hard_disk_path("DL")[:-1] + "_CV/"
TRAIN_FEATURES_PATH_0 = FILE_PATH + 'dead' 
TRAIN_FEATURES_PATH_1 = FILE_PATH + 'empty'
TRAIN_FEATURES_PATH_2 = FILE_PATH + 'keep0'
TRAIN_FEATURES_PATH_3 = FILE_PATH + 'keep1'
TRAIN_FEATURES_PATH_4 = FILE_PATH + 'keep2'
TRAIN_FEATURES_PATH_5 = FILE_PATH + 'reseed0'
TRAIN_FEATURES_PATH_6 = FILE_PATH + 'reseed1'
TRAIN_FEATURES_PATH_7 = FILE_PATH + 'split'

# list with pathe
PATHES_LIST = [TRAIN_FEATURES_PATH_0,TRAIN_FEATURES_PATH_1,TRAIN_FEATURES_PATH_2,TRAIN_FEATURES_PATH_3,TRAIN_FEATURES_PATH_4, TRAIN_FEATURES_PATH_5, TRAIN_FEATURES_PATH_6, TRAIN_FEATURES_PATH_7]
# Out:
# Successfully loaded data from E:/data_for_DL/

# %% [markdown]
# # Data set : train & test

# %% [markdown]
# The data was divided into training and testing sets for each class, with a split of 80% for training and 20% for testing, maintaining the same ratio for each class. However, the dataset exhibits an imbalance issue, with one class having a significantly larger number of samples compared to the other class.

# %%
labels = ['dead', 'empty', 'keep0', 'keep1', 'keep2', 'reseed0', 'reseed1', 'split']
for i, path in enumerate(PATHES_LIST):
    print(path)
# Out:
# E:/data_for_DL_CV/dead
# E:/data_for_DL_CV/empty
# E:/data_for_DL_CV/keep0
# E:/data_for_DL_CV/keep1
# E:/data_for_DL_CV/keep2
# E:/data_for_DL_CV/reseed0
# E:/data_for_DL_CV/reseed1
# E:/data_for_DL_CV/split

# %%
class CustomImageDataset_train(Dataset):
    def __init__(self, img_paths, img_labels, transform=None, model_name=None):
        self.img_sort = img_paths
        self.img_labels = img_labels
        self.transform = transform
        self.processor = None

        # Load the processor if a model name is given
        if model_name == "microsoft/resnet-50":
            self.processor = AutoImageProcessor.from_pretrained(model_name)
        if model_name == "microsoft/resnet-18":
            self.processor = AutoFeatureExtractor.from_pretrained(model_name)
        if model_name == "microsoft/beit-base-patch16-224-pt22k-ft22k":
            self.processor = BeitImageProcessor.from_pretrained(model_name)
        if model_name == "google/vit-base-patch16-224":
            self.processor = ViTImageProcessor.from_pretrained(model_name)

        self.len = len(self.img_sort)

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        img_path = self.img_sort[idx]
        try:
            image = read_image(img_path).float()
        except Exception as e:
            print(f"Error reading image {img_path}: {e}")
            # Handle error (e.g., by skipping this sample or using a default image)

        label = torch.tensor(self.img_labels[idx], dtype=torch.long)

        if image.shape[0] == 1:
            image = image.repeat(3, 1, 1)

        if self.transform:
            image = self.transform(image)

        image = self.augmentation(image)

        if self.processor:
            image = self.processor(images=image, return_tensors="pt").pixel_values.squeeze()

        return image, label
        
    def augmentation(self, image):
        # Random horizontal flipping
        if random.random() > 0.5:
            image = TF.hflip(image)

        # Random vertical flipping
        if random.random() > 0.5:
            image = TF.vflip(image)

        # Random rotation by 0, 90, 180, or 270 degrees
        degree = random.choice([0, 90, 180, 270])
        image = TF.rotate(image, degree)

        return image

# %% [markdown]
# ### Separate data to train and test data with ratio 0.8 in test data

# %% [markdown]
# To utilize the CustomImageDataset_test and CustomImageDataset_train, it is necessary to specify the desired transformations for each case, such as Normalize and CenterCrop.
#
# The following code demonstrates how to define the transformations:
#
# For test data transformation using CenterCrop:

# %%
class CustomImageDataset_test(Dataset):
    def __init__(self, img_paths, img_labels, transform=None, model_name=None):
        self.img_sort = img_paths   # List of image paths
        self.img_labels = img_labels # Corresponding labels for each image
        self.transform = transform
        self.processor = None

        # Load the processor if a model name is given
        if model_name == "microsoft/resnet-50":
            self.processor = AutoImageProcessor.from_pretrained(model_name)
        if model_name == "microsoft/resnet-18":
            self.processor = AutoFeatureExtractor.from_pretrained(model_name)
        if model_name == "microsoft/beit-base-patch16-224-pt22k-ft22k":
            self.processor = BeitImageProcessor.from_pretrained(model_name)
        if model_name == "google/vit-base-patch16-224":
            self.processor = ViTImageProcessor.from_pretrained(model_name)
        
        self.len = len(self.img_sort)

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        img_path = self.img_sort[idx]
        try:
            image = read_image(img_path).float()
        except Exception as e:
            print(f"Error reading image {img_path}: {e}")
            # Handle error (e.g., by skipping this sample or using a default image)

        label = torch.tensor(self.img_labels[idx], dtype=torch.long)

        if image.shape[0] == 1:
            image = image.repeat(3, 1, 1)

        if self.transform:
            image = self.transform(image)

        if self.processor:
            image = self.processor(images=image, return_tensors="pt").pixel_values.squeeze()

        return image, label

# %%
import torch
import wandb
from sklearn.metrics import f1_score
from torch.utils.data import DataLoader
from sklearn.model_selection import StratifiedKFold
import csv

model_names = ["microsoft/resnet-50", "microsoft/resnet-18", "microsoft/beit-base-patch16-224-pt22k-ft22k", "google/vit-base-patch16-224"]

for model_name in model_names:
    # Initialize a new wandb run
    wandb.init(project="organoid_classification", entity="laurent-gurtler")

    num_epochs = 50
    learning_rate = 5e-5
    batch_size = 32
    k_folds = 5
    weight_decay = 1e-5

    config = wandb.config
    config.learning_rate = learning_rate
    config.batch_size = batch_size
    config.num_epochs = num_epochs
    config.k_folds = k_folds
    config.weight_decay = weight_decay


    all_labels_list = ['dead', 'empty', 'keep0', 'keep1', 'keep2', 'reseed0', 'reseed1', 'split']

    all_fold_f1_scores = []
    num_labels = len(all_labels_list)  # The number of unique labels/classes in your dataset

    # Assuming PATHES_LIST contains paths to your different class directories
    img_labels = []
    img_sort = []
    for i, img_dir in enumerate(PATHES_LIST):
        img_files = sorted([f for f in os.listdir(img_dir) if f.endswith(".jpg")])
        img_labels.extend([i] * len(img_files))  # Labels for each image
        img_sort.extend([os.path.join(img_dir, f) for f in img_files])  # Paths for each image

    # Convert img_sort to a numpy array for easier indexing
    img_sort = np.array(img_sort)

    # Initialize StratifiedKFold
    kf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

    # Convert img_labels to numpy array for StratifiedKFold
    img_labels = np.array(img_labels)

    for fold, (train_idx, val_idx) in enumerate(kf.split(img_sort, img_labels)):
        print(f"Training on fold {fold+1}/{k_folds}")
        if "beit" in model_name:
            config = BeitConfig.from_pretrained(model_name, num_labels=num_labels)
            model = BeitForImageClassification(config)
        elif "resnet" in model_name:
            config = ResNetConfig.from_pretrained(model_name, num_labels=num_labels)
            model = ResNetForImageClassification(config)
        elif "vit" in model_name:
            config = ViTConfig.from_pretrained(model_name, num_labels=num_labels)
            model = ViTForImageClassification(config)
        criterion = torch.nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

        # Split data into training and validation for this fold
        train_data = img_sort[train_idx]
        val_data = img_sort[val_idx]

        # Create datasets for this fold
        train_dataset = CustomImageDataset_train(train_data, img_labels[train_idx], 
                                                transform=False, 
                                                model_name=model_name)
        test_dataset = CustomImageDataset_test(val_data, img_labels[val_idx], 
                                            transform=False, 
                                            model_name=model_name)
        

        test_loader = DataLoader(test_dataset, shuffle=False)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(device)
        model.to(device)

        wandb.watch(model, criterion, log="all", log_freq=10)

        epoch_f1_scores_dict_list = []

        for epoch in range(num_epochs):
            model.train()
            running_loss = 0.0
            for images, labels in train_loader:
                images = images.to(device)
                labels = labels.to(device)  # Convert labels to torch.long
                optimizer.zero_grad()
                outputs = model(images).logits
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
            
            wandb.log({"fold": fold+1, "epoch": epoch, "train_loss": running_loss/len(train_loader)})

            # Validation phase
            model.eval()
            all_labels = []
            all_predictions = []
            validation_loss = 0.0
            correct = 0
            total = 0

            with torch.no_grad():
                for images, labels in test_loader:
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images).logits
                    predicted = outputs.argmax(dim=1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    loss = criterion(outputs, labels)
                    validation_loss += loss.item()

                    # Move the labels and predictions to CPU for sklearn metrics
                    all_labels.extend(labels.cpu().numpy())
                    all_predictions.extend(predicted.cpu().numpy())

            # Calculate accuracy and F1 score
            accuracy = 100 * correct / total
            f1_scores = f1_score(all_labels, all_predictions, average=None, zero_division=0)  # This will give you an array of F1 scores per class
            # Check if the length of F1 scores matches the number of labels
            if len(f1_scores) != len(all_labels_list):
                print(f"Warning: Number of F1 scores ({len(f1_scores)}) does not match number of classes ({len(all_labels_list)})")
                # Trim the list of F1 scores to match the number of classes, if necessary
                f1_scores = f1_scores[:len(all_labels_list)]

            # Create a dictionary of class labels and their corresponding F1 scores
            f1_scores_dict = {all_labels_list[idx]: f1 for idx, f1 in enumerate(f1_scores)}
            epoch_f1_scores_dict_list.append(f1_scores_dict)

            # It might be useful to also get the classification report for all metrics
            classification_rep = classification_report(all_labels, all_predictions, output_dict=True, zero_division=0)

            # Logging the individual F1 scores
            for idx, f1 in enumerate(f1_scores):
                wandb.log({f"class_{idx}_f1_score": f1})


            wandb.log({"fold": fold+1, "epoch": epoch, "val_loss": validation_loss/len(test_loader), "val_accuracy": accuracy})

            # Print statistics for each class
            print(f"Epoch {epoch+1}, Train Loss: {running_loss/len(train_loader)}, "
                f"Validation Loss: {validation_loss/len(test_loader)}, Accuracy: {accuracy} %")
            for idx, f1 in enumerate(f1_scores):
                print(f"Class {idx} F1 Score: {f1}")

            for idx, f1 in enumerate(f1_scores):
                wandb.log({f"class_{idx}_f1_score": f1})

        # Access the F1-scores for the last epoch
            # Access the F1-scores for the last epoch of this fold
        last_epoch_f1_scores = epoch_f1_scores_dict_list[-1]

        # Append model name, fold number, and F1 scores to the list
        fold_data = {"model_name": model_name, "fold": fold + 1}
        fold_data.update(last_epoch_f1_scores)
        all_fold_f1_scores.append(fold_data)

        # Clear the epoch_f1_scores_dict_list for the next fold
        epoch_f1_scores_dict_list.clear()

        # The last_epoch_f1_scores already contains the F1 scores for each class from the last epoch
        # Optionally, you can directly plot these scores if needed
        plot_average_f1_scores(all_labels_list, last_epoch_f1_scores)


        # After the loop, you may want to log the overall performance
        wandb.log({
            "fold": fold+1, "final_accuracy": accuracy,
            "fold": fold+1, "final_f1_scores": f1_scores.tolist(),  # Convert to list if necessary
            "fold": fold+1, "final_classification_report": classification_rep
        })

        csv_filename = FILE_PATH + 'f1_scores_per_fold.csv'
        existing_data = []

        # Read existing data
        if os.path.exists(csv_filename):
            with open(csv_filename, 'r') as file:
                reader = csv.DictReader(file)
                existing_data = [row for row in reader]

        # Update or append new data
        for new_data in all_fold_f1_scores:
            model_found = False
            for existing_row in existing_data:
                if existing_row['model_name'] == new_data['model_name'] and existing_row['fold'] == str(new_data['fold']):
                    # Update existing row with new data
                    for key, value in new_data.items():
                        existing_row[key] = value
                    model_found = True
                    break
            if not model_found:
                # Convert numeric values to strings for CSV writing
                new_data_string = {k: str(v) for k, v in new_data.items()}
                existing_data.append(new_data_string)

        # Write updated data back to CSV
        header = ['model_name', 'fold'] + all_labels_list

        with open(csv_filename, 'w', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=header)
            writer.writeheader()
            for data_row in existing_data:
                writer.writerow(data_row)

    # Close the wandb run
    wandb.finish()
# Out:
# Finishing last run (ID:m667nt35) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>class_0_f1_score</td><td>▁▅▅▇▃▆▆▆▆█▅▁▃▁▁▃▁▅▅▁▅▁▂▃▁▁▁▃▁▃▃▁▄▅▄▃▆▄▇▅</td></tr><tr><td>class_1_f1_score</td><td>▄▇▅█▅██▅█▇▅▁▁▁▅▅▁▆▁▅▁▅▁▇▅▁▁▁▁▅▅▃▁▁▁▁███▇</td></tr><tr><td>class_2_f1_score</td><td>▁▄▄▆▅▄▆▄▄▅▄▂████▇▇█▇█▅▇▇██▇█▇▇█▃▄▄▄▇▄▇▇▇</td></tr><tr><td>class_3_f1_score</td><td>▁▇▅▅▆▆▆▇█▆▇▁▅▄▇█▆▆▇▇▇▂▇▄▅▆▆█▇▅▇▁▅▅▆▄▇▇▇▇</td></tr><tr><td>class_4_f1_score</td><td>▁▆█▁▅▁█▄▇▆█▅▁▁▅█▆▅▆▅▁▅▇▅▁█▁▁▁▁█▁▁▁▅▁█▅▇▆</td></tr><tr><td>class_5_f1_score</td><td>▁▅▁▆▅▆▁▁▆▁▁█▁▁▆█▇██▆▆███▆██▁██▁▁▅▅▁█▅▁██</td></tr><tr><td>class_6_f1_score</td><td>▁▁▁▁▆▆▇▁▅▁▄▁▁▁█▁▁▁██▆▁▁█▁▅▅▆▄█▅▁▁▁▆▁▁▅▆▁</td></tr><tr><td>class_7_f1_score</td><td>▁▁▁▁▁▄▇█▁▁▁▁▅▃▆▆▄▆▁▇▁▁▁▁▃▆▁▃▁▃▁▁▁▅▁▁▅▃▅█</td></tr><tr><td>epoch</td><td>▁▂▂▃▄▅▅▆▇▇█▁▂▃▄▄▅▆▆▇█▁▂▃▃▄▅▅▆▇█▁▂▂▃▄▅▅▆▇</td></tr><tr><td>final_accuracy</td><td>▁▁█</td></tr><tr><td>fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▆▆▆▆▆▆▆▆▆▆█████████</td></tr><tr><td>train_loss</td><td>█▇▅▄▃▃▃▄▂▂▁▆▆▃▄▃▃▂▃▂▃▇▅▄▃▄▃▃▂▁▂█▆▄▃▃▄▂▂▂</td></tr><tr><td>val_accuracy</td><td>▁▅▅▆▅▆▇▅▇▆▅▂▅▃▇▇▅▇▇▇▆▃▅▅▅▇▅▅▅▅▆▁▃▄▄▄▇▆█▇</td></tr><tr><td>val_loss</td><td>▆▄▄▃▃▃▂▁▁▁▃▆▆▄▂▂▅▂▂▂▅▄▅▄▅▅▆█▅▃▂▇▄▅▇▄▃▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>class_0_f1_score</td><td>0.5</td></tr><tr><td>class_1_f1_score</td><td>0.0</td></tr><tr><td>class_2_f1_score</td><td>0.88889</td></tr><tr><td>class_3_f1_score</td><td>0.53333</td></tr><tr><td>class_4_f1_score</td><td>0.0</td></tr><tr><td>class_5_f1_score</td><td>0.0</td></tr><tr><td>class_6_f1_score</td><td>0.57143</td></tr><tr><td>class_7_f1_score</td><td>0.57143</td></tr><tr><td>epoch</td><td>41</td></tr><tr><td>final_accuracy</td><td>72.0</td></tr><tr><td>fold</td><td>4</td></tr><tr><td>train_loss</td><td>0.8598</td></tr><tr><td>val_accuracy</td><td>52.0</td></tr><tr><td>val_loss</td><td>1.56725</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">solar-haze-91</strong> at: <a href='https://wandb.ai/laurent-gurtler/organoid_classification/runs/m667nt35' target="_blank">https://wandb.ai/laurent-gurtler/organoid_classification/runs/m667nt35</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231121_121346-m667nt35\logs</code>
# Successfully finished last run (ID:m667nt35). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>c:\Users\lguertle\organoids-project\notebooks\wandb\run-20231121_134030-6l7gigu7</code>
# Syncing run <strong><a href='https://wandb.ai/laurent-gurtler/organoid_classification/runs/6l7gigu7' target="_blank">electric-breeze-92</a></strong> to <a href='https://wandb.ai/laurent-gurtler/organoid_classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/laurent-gurtler/organoid_classification' target="_blank">https://wandb.ai/laurent-gurtler/organoid_classification</a>
#  View run at <a href='https://wandb.ai/laurent-gurtler/organoid_classification/runs/6l7gigu7' target="_blank">https://wandb.ai/laurent-gurtler/organoid_classification/runs/6l7gigu7</a>
# Training on fold 1/5
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# cuda
# Epoch 1, Train Loss: 2.0544409453868866, Validation Loss: 2.0756793880462645, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.2222222222222222
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 2, Train Loss: 1.7342490553855896, Validation Loss: 2.065175676345825, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 3, Train Loss: 1.9308917820453644, Validation Loss: 2.0971652364730833, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 4, Train Loss: 1.9195967018604279, Validation Loss: 2.145471444129944, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 5, Train Loss: 1.702545553445816, Validation Loss: 2.146349229812622, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 6, Train Loss: 1.6462802290916443, Validation Loss: 2.1295305490493774, Accuracy: 20.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2105263157894737
# Class 3 F1 Score: 0.4
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 7, Train Loss: 1.6269512176513672, Validation Loss: 2.1193999290466308, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.22222222222222224
# Class 3 F1 Score: 0.4
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 8, Train Loss: 1.771066427230835, Validation Loss: 2.149105257987976, Accuracy: 20.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.37037037037037035
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 9, Train Loss: 1.4950954914093018, Validation Loss: 2.171888082027435, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.37037037037037035
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 10, Train Loss: 1.632599949836731, Validation Loss: 2.1716419363021853, Accuracy: 28.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4
# Class 2 F1 Score: 0.3333333333333333
# Class 3 F1 Score: 0.3846153846153846
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 11, Train Loss: 1.403821885585785, Validation Loss: 2.1003366148471834, Accuracy: 28.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.28571428571428575
# Class 3 F1 Score: 0.3846153846153846
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 12, Train Loss: 1.3684615194797516, Validation Loss: 1.9341364407539368, Accuracy: 32.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.3333333333333333
# Class 3 F1 Score: 0.47619047619047616
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 13, Train Loss: 1.3329506516456604, Validation Loss: 1.8427885031700135, Accuracy: 32.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.4285714285714285
# Class 3 F1 Score: 0.4210526315789473
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 14, Train Loss: 1.3859802186489105, Validation Loss: 1.7203512769937515, Accuracy: 36.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.39999999999999997
# Class 3 F1 Score: 0.42857142857142855
# Class 4 F1 Score: 0.28571428571428575
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 15, Train Loss: 1.231346607208252, Validation Loss: 1.6154582795500756, Accuracy: 40.0 %
# Class 0 F1 Score: 0.5714285714285715
# Class 1 F1 Score: 0.4
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.42857142857142855
# Class 4 F1 Score: 0.28571428571428575
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 16, Train Loss: 1.3668532073497772, Validation Loss: 1.4463596074283123, Accuracy: 44.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.6666666666666666
# Class 2 F1 Score: 0.6
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 17, Train Loss: 1.3210092186927795, Validation Loss: 1.4011577992141246, Accuracy: 44.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.4
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.4
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.4
# Class 7 F1 Score: 0.0
# Epoch 18, Train Loss: 0.9933807849884033, Validation Loss: 1.3025334575027228, Accuracy: 52.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.0
# Epoch 19, Train Loss: 1.1670882254838943, Validation Loss: 1.2779246698319913, Accuracy: 48.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 1.0
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.45454545454545453
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 20, Train Loss: 1.2474379986524582, Validation Loss: 1.2291632583364844, Accuracy: 48.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.7499999999999999
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5882352941176471
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 21, Train Loss: 0.9876135140657425, Validation Loss: 1.184275848735124, Accuracy: 52.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.7499999999999999
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.625
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 22, Train Loss: 1.2252584397792816, Validation Loss: 1.2567601406481117, Accuracy: 44.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.6666666666666666
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 23, Train Loss: 1.2784049212932587, Validation Loss: 1.2192274677380919, Accuracy: 52.0 %
# Class 0 F1 Score: 0.6666666666666666
# Class 1 F1 Score: 0.5714285714285715
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5882352941176471
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 24, Train Loss: 0.9681556224822998, Validation Loss: 1.2533367123454808, Accuracy: 48.0 %
# Class 0 F1 Score: 0.46153846153846156
# Class 1 F1 Score: 1.0
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.4615384615384615
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 25, Train Loss: 0.9176240116357803, Validation Loss: 1.2459310702607036, Accuracy: 48.0 %
# Class 0 F1 Score: 0.5454545454545454
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5333333333333333
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.5
# Epoch 26, Train Loss: 1.0314321368932724, Validation Loss: 1.1699973291624337, Accuracy: 64.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.625
# Class 4 F1 Score: 0.6666666666666666
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.5
# Epoch 27, Train Loss: 1.1273202002048492, Validation Loss: 1.433830407653004, Accuracy: 56.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.5714285714285715
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.5714285714285715
# Epoch 28, Train Loss: 0.9866653680801392, Validation Loss: 1.5109857897181065, Accuracy: 40.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5555555555555556
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.28571428571428575
# Epoch 29, Train Loss: 0.9655398428440094, Validation Loss: 1.5203465553559363, Accuracy: 52.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.625
# Class 4 F1 Score: 0.5714285714285715
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.5
# Epoch 30, Train Loss: 1.0494780242443085, Validation Loss: 1.2794898016750813, Accuracy: 52.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.8571428571428571
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.3636363636363636
# Epoch 31, Train Loss: 0.7829481214284897, Validation Loss: 1.327934566643089, Accuracy: 52.0 %
# Class 0 F1 Score: 0.6
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.5333333333333333
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.6666666666666666
# Epoch 32, Train Loss: 0.8894699066877365, Validation Loss: 1.4676979056932031, Accuracy: 40.0 %
# Class 0 F1 Score: 0.39999999999999997
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 33, Train Loss: 1.0562321543693542, Validation Loss: 1.1391168571962043, Accuracy: 60.0 %
# Class 0 F1 Score: 0.6
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.6666666666666666
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 34, Train Loss: 0.8858553171157837, Validation Loss: 1.1558747658343054, Accuracy: 72.0 %
# Class 0 F1 Score: 0.6666666666666666
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.9090909090909091
# Class 4 F1 Score: 0.7272727272727273
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.5
# Epoch 35, Train Loss: 0.7852237224578857, Validation Loss: 1.0994123721122742, Accuracy: 44.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.625
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 36, Train Loss: 0.9194878488779068, Validation Loss: 1.2373409119597636, Accuracy: 56.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5555555555555556
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.6666666666666666
# Epoch 37, Train Loss: 0.7681908458471298, Validation Loss: 1.0422245465382003, Accuracy: 68.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.7142857142857143
# Class 4 F1 Score: 0.5
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.6666666666666666
# Epoch 38, Train Loss: 0.7117959707975388, Validation Loss: 1.2247260881215334, Accuracy: 60.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.5714285714285715
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 39, Train Loss: 0.8371037840843201, Validation Loss: 1.0705625033471733, Accuracy: 60.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5454545454545454
# Class 4 F1 Score: 0.5
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.6666666666666666
# Epoch 40, Train Loss: 0.9518345296382904, Validation Loss: 0.9405295627564192, Accuracy: 68.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.6666666666666666
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.8
# Epoch 41, Train Loss: 0.9548289626836777, Validation Loss: 1.0021847065538168, Accuracy: 64.0 %
# Class 0 F1 Score: 1.0
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.5882352941176471
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.8
# Epoch 42, Train Loss: 0.9337129890918732, Validation Loss: 1.2432300635240972, Accuracy: 52.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 0.6666666666666666
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.5555555555555556
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 43, Train Loss: 1.257503479719162, Validation Loss: 1.4144858673214913, Accuracy: 56.0 %
# Class 0 F1 Score: 1.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.5882352941176471
# Class 4 F1 Score: 0.6666666666666666
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 44, Train Loss: 0.9636998921632767, Validation Loss: 1.266491963006556, Accuracy: 56.0 %
# Class 0 F1 Score: 0.888888888888889
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.5
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 45, Train Loss: 0.7139187306165695, Validation Loss: 1.4720885904389434, Accuracy: 44.0 %
# Class 0 F1 Score: 0.6666666666666666
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.47058823529411764
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 46, Train Loss: 0.8852227628231049, Validation Loss: 1.3077026799996383, Accuracy: 56.0 %
# Class 0 F1 Score: 0.6666666666666666
# Class 1 F1 Score: 0.8
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.6666666666666665
# Class 4 F1 Score: 0.5333333333333333
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 47, Train Loss: 0.7958449274301529, Validation Loss: 0.9153191318362951, Accuracy: 68.0 %
# Class 0 F1 Score: 0.8571428571428571
# Class 1 F1 Score: 1.0
# Class 2 F1 Score: 0.5714285714285715
# Class 3 F1 Score: 0.6666666666666665
# Class 4 F1 Score: 0.6153846153846153
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 48, Train Loss: 0.5390109568834305, Validation Loss: 0.9376780590415001, Accuracy: 76.0 %
# Class 0 F1 Score: 0.8
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.8000000000000002
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 0.8
# Epoch 49, Train Loss: 0.8714830726385117, Validation Loss: 1.0499703564774245, Accuracy: 72.0 %
# Class 0 F1 Score: 0.75
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.6666666666666666
# Class 3 F1 Score: 0.7142857142857143
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 1.0
# Epoch 50, Train Loss: 0.8325962796807289, Validation Loss: 1.6822141973866382, Accuracy: 56.0 %
# Class 0 F1 Score: 0.6666666666666666
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.5555555555555556
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Training on fold 2/5
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# cuda
# Epoch 1, Train Loss: 2.100132077932358, Validation Loss: 2.070244469642639, Accuracy: 0.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 2, Train Loss: 2.0043130218982697, Validation Loss: 2.1005497980117798, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 3, Train Loss: 1.6981559097766876, Validation Loss: 2.1767819833755495, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 4, Train Loss: 1.6729985475540161, Validation Loss: 2.2706200313568115, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 5, Train Loss: 1.7601489126682281, Validation Loss: 2.3780061769485474, Accuracy: 20.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.2608695652173913
# Class 2 F1 Score: 0.4444444444444445
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 6, Train Loss: 1.6665595173835754, Validation Loss: 2.407131061553955, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.23076923076923078
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 7, Train Loss: 1.6572131216526031, Validation Loss: 2.426751959323883, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.23076923076923078
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 8, Train Loss: 1.703993558883667, Validation Loss: 2.4383534359931947, Accuracy: 8.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.16666666666666666
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 9, Train Loss: 1.5425939559936523, Validation Loss: 2.4082324504852295, Accuracy: 8.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.09090909090909091
# Class 2 F1 Score: 0.2
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 10, Train Loss: 1.5850046873092651, Validation Loss: 2.2747056460380555, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.3157894736842105
# Class 2 F1 Score: 0.46153846153846156
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 11, Train Loss: 1.4794100522994995, Validation Loss: 2.2164962816238405, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.3
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 12, Train Loss: 1.4134441018104553, Validation Loss: 2.1646317756175995, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.3
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 13, Train Loss: 1.6678583323955536, Validation Loss: 2.1780557000637053, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.3157894736842105
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 14, Train Loss: 1.3923511803150177, Validation Loss: 2.108265789151192, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.3
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 15, Train Loss: 1.338978350162506, Validation Loss: 2.036541426181793, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.33333333333333337
# Class 2 F1 Score: 0.46153846153846156
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 16, Train Loss: 1.5493308007717133, Validation Loss: 1.810634024143219, Accuracy: 28.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.375
# Class 2 F1 Score: 0.4285714285714285
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 17, Train Loss: 1.634812831878662, Validation Loss: 1.609024882912636, Accuracy: 40.0 %
# Class 0 F1 Score: 0.28571428571428575
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.6666666666666665
# Class 3 F1 Score: 0.4
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 18, Train Loss: 1.0550811886787415, Validation Loss: 1.617499992698431, Accuracy: 36.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.47058823529411764
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 19, Train Loss: 1.166413962841034, Validation Loss: 1.590966256186366, Accuracy: 36.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.47058823529411764
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 20, Train Loss: 1.269973874092102, Validation Loss: 1.474746102541685, Accuracy: 48.0 %
# Class 0 F1 Score: 0.28571428571428575
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.6666666666666665
# Class 3 F1 Score: 0.5454545454545454
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 21, Train Loss: 1.3516676276922226, Validation Loss: 1.4551667855679988, Accuracy: 44.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.4
# Class 2 F1 Score: 0.6666666666666665
# Class 3 F1 Score: 0.5714285714285715
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.5714285714285715
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 22, Train Loss: 1.2511954009532928, Validation Loss: 1.4574946402013302, Accuracy: 40.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.375
# Class 2 F1 Score: 0.6666666666666665
# Class 3 F1 Score: 0.33333333333333337
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 23, Train Loss: 1.1321232318878174, Validation Loss: 1.3089180924743413, Accuracy: 44.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.6
# Class 2 F1 Score: 0.6666666666666665
# Class 3 F1 Score: 0.5714285714285715
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.22222222222222224
# Epoch 24, Train Loss: 1.0344005823135376, Validation Loss: 1.2206160812079907, Accuracy: 48.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.5000000000000001
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.0
# Epoch 25, Train Loss: 1.2893598824739456, Validation Loss: 1.1957907262444496, Accuracy: 48.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.47058823529411764
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.0
# Epoch 26, Train Loss: 1.1891166269779205, Validation Loss: 1.2761510859429837, Accuracy: 48.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.5714285714285714
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.0
# Epoch 27, Train Loss: 1.0793960392475128, Validation Loss: 1.2622798724472524, Accuracy: 52.0 %
# Class 0 F1 Score: 0.3333333333333333
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6153846153846154
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.0
# Epoch 28, Train Loss: 0.8549209162592888, Validation Loss: 1.2188486149907112, Accuracy: 40.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.4444444444444445
# Class 4 F1 Score: 0.18181818181818182
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 29, Train Loss: 1.3839161694049835, Validation Loss: 1.2617376121133566, Accuracy: 48.0 %
# Class 0 F1 Score: 0.25
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.33333333333333337
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 30, Train Loss: 1.0143946558237076, Validation Loss: 1.1379573625698685, Accuracy: 48.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.888888888888889
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 31, Train Loss: 1.2266832888126373, Validation Loss: 1.2171805419027806, Accuracy: 56.0 %
# Class 0 F1 Score: 0.5714285714285715
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.8
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 32, Train Loss: 1.164073497056961, Validation Loss: 1.171870190575719, Accuracy: 52.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6153846153846154
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 33, Train Loss: 0.8564586192369461, Validation Loss: 1.2002822744101287, Accuracy: 56.0 %
# Class 0 F1 Score: 0.5714285714285715
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 34, Train Loss: 1.0136895030736923, Validation Loss: 1.253661103695631, Accuracy: 56.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 35, Train Loss: 1.0814489275217056, Validation Loss: 1.2691259957849979, Accuracy: 52.0 %
# Class 0 F1 Score: 0.30769230769230765
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.7499999999999999
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 36, Train Loss: 1.1523160487413406, Validation Loss: 1.1351443003863095, Accuracy: 56.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.4444444444444444
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.6666666666666665
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.0
# Epoch 37, Train Loss: 1.0019826591014862, Validation Loss: 1.1274725057184696, Accuracy: 56.0 %
# Class 0 F1 Score: 0.28571428571428575
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.75
# Class 3 F1 Score: 0.7499999999999999
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.25
# Epoch 38, Train Loss: 0.9937274307012558, Validation Loss: 1.0794584404677152, Accuracy: 56.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6666666666666665
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 0.4444444444444445
# Epoch 39, Train Loss: 0.9511438757181168, Validation Loss: 1.1066498360037804, Accuracy: 56.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.25
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.5
# Epoch 40, Train Loss: 0.7848445773124695, Validation Loss: 1.2541093823313714, Accuracy: 56.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.5714285714285715
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.6666666666666666
# Epoch 41, Train Loss: 0.9395948946475983, Validation Loss: 1.1714591623842716, Accuracy: 64.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.5714285714285715
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.7692307692307693
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 0.6666666666666666
# Epoch 42, Train Loss: 0.6474740244448185, Validation Loss: 0.9283942152559758, Accuracy: 60.0 %
# Class 0 F1 Score: 0.3333333333333333
# Class 1 F1 Score: 0.6666666666666666
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.6666666666666665
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.0
# Epoch 43, Train Loss: 0.8840245753526688, Validation Loss: 0.9852252757176757, Accuracy: 56.0 %
# Class 0 F1 Score: 0.6
# Class 1 F1 Score: 0.5714285714285715
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.28571428571428575
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.4444444444444445
# Class 7 F1 Score: 0.0
# Epoch 44, Train Loss: 0.9451012313365936, Validation Loss: 1.0228348053619265, Accuracy: 56.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 45, Train Loss: 0.7830857634544373, Validation Loss: 0.9473556695133447, Accuracy: 64.0 %
# Class 0 F1 Score: 0.8
# Class 1 F1 Score: 0.5714285714285715
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.8
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 0.0
# Epoch 46, Train Loss: 1.1410322338342667, Validation Loss: 1.0086519841849804, Accuracy: 60.0 %
# Class 0 F1 Score: 0.5454545454545454
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.8
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.0
# Epoch 47, Train Loss: 0.8451197892427444, Validation Loss: 0.9908665180206299, Accuracy: 60.0 %
# Class 0 F1 Score: 0.5454545454545454
# Class 1 F1 Score: 0.5714285714285715
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6666666666666665
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.8
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.0
# Epoch 48, Train Loss: 0.6877109557390213, Validation Loss: 1.0422714960947632, Accuracy: 56.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.7499999999999999
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 49, Train Loss: 0.8849919587373734, Validation Loss: 1.115363928079605, Accuracy: 56.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.5
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.7499999999999999
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 50, Train Loss: 0.7922339737415314, Validation Loss: 0.8703788464888931, Accuracy: 56.0 %
# Class 0 F1 Score: 0.3333333333333333
# Class 1 F1 Score: 0.7499999999999999
# Class 2 F1 Score: 0.8571428571428571
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.22222222222222224
# Training on fold 3/5
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# cuda
# Epoch 1, Train Loss: 2.0523571968078613, Validation Loss: 2.0526797342300416, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.24999999999999997
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 2, Train Loss: 1.8526447117328644, Validation Loss: 2.024772663116455, Accuracy: 20.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.33333333333333337
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 3, Train Loss: 1.6468967199325562, Validation Loss: 2.0473188972473144, Accuracy: 20.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.33333333333333337
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 4, Train Loss: 1.6355930268764496, Validation Loss: 2.1278131675720213, Accuracy: 32.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4615384615384615
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 5, Train Loss: 1.6890716254711151, Validation Loss: 2.2569395160675048, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.21428571428571425
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 6, Train Loss: 1.5710358023643494, Validation Loss: 2.4125429940223695, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.21428571428571425
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 7, Train Loss: 1.4852391183376312, Validation Loss: 2.5088472843170164, Accuracy: 12.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.21428571428571425
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 8, Train Loss: 1.482435554265976, Validation Loss: 2.489264371395111, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.23076923076923078
# Class 2 F1 Score: 0.28571428571428575
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 9, Train Loss: 1.5118160843849182, Validation Loss: 2.3999252271652223, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.2727272727272727
# Class 2 F1 Score: 0.5454545454545454
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 10, Train Loss: 1.3875261545181274, Validation Loss: 2.302946214675903, Accuracy: 24.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.2857142857142857
# Class 2 F1 Score: 0.5
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 11, Train Loss: 1.3223528861999512, Validation Loss: 2.215694607496262, Accuracy: 28.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.35294117647058826
# Class 2 F1 Score: 0.5000000000000001
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 12, Train Loss: 1.4726333320140839, Validation Loss: 2.0498691534996034, Accuracy: 32.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.4615384615384615
# Class 2 F1 Score: 0.5263157894736842
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 13, Train Loss: 1.2855230271816254, Validation Loss: 1.889512881040573, Accuracy: 36.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.6
# Class 2 F1 Score: 0.5882352941176471
# Class 3 F1 Score: 0.2
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 14, Train Loss: 1.309694766998291, Validation Loss: 1.6988119176030159, Accuracy: 36.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.6666666666666666
# Class 2 F1 Score: 0.5882352941176471
# Class 3 F1 Score: 0.18181818181818182
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 15, Train Loss: 1.2958727180957794, Validation Loss: 1.491560382694006, Accuracy: 40.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.7499999999999999
# Class 2 F1 Score: 0.5555555555555556
# Class 3 F1 Score: 0.4
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 16, Train Loss: 1.361226350069046, Validation Loss: 1.3570005604997277, Accuracy: 44.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.7499999999999999
# Class 2 F1 Score: 0.7142857142857143
# Class 3 F1 Score: 0.30769230769230765
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 17, Train Loss: 1.3250155299901962, Validation Loss: 1.194099167920649, Accuracy: 56.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.4
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 18, Train Loss: 1.2620967328548431, Validation Loss: 1.1735989336483181, Accuracy: 56.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.5454545454545454
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.4
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.3333333333333333
# Epoch 19, Train Loss: 1.1797305941581726, Validation Loss: 1.1688127962965518, Accuracy: 52.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.33333333333333337
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 20, Train Loss: 1.1216756105422974, Validation Loss: 1.1499904297105967, Accuracy: 60.0 %
# Class 0 F1 Score: 0.4444444444444444
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.7272727272727273
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.5
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 21, Train Loss: 1.1209487915039062, Validation Loss: 1.1884692274965345, Accuracy: 64.0 %
# Class 0 F1 Score: 0.36363636363636365
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.888888888888889
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 22, Train Loss: 1.0728832334280014, Validation Loss: 1.0539533781632782, Accuracy: 60.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.5454545454545454
# Class 4 F1 Score: 0.5
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 23, Train Loss: 1.0762487947940826, Validation Loss: 1.035926047116518, Accuracy: 60.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.5454545454545454
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 24, Train Loss: 0.8971559554338455, Validation Loss: 1.0936242458224297, Accuracy: 64.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.6666666666666665
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 25, Train Loss: 0.9779590666294098, Validation Loss: 1.0273128374665976, Accuracy: 64.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.6666666666666665
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 26, Train Loss: 0.9275179654359818, Validation Loss: 0.8472101573646068, Accuracy: 72.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.8
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 0.4
# Epoch 27, Train Loss: 1.0684374123811722, Validation Loss: 0.8635629121586681, Accuracy: 68.0 %
# Class 0 F1 Score: 0.3333333333333333
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.888888888888889
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 28, Train Loss: 0.8735677152872086, Validation Loss: 0.8584966146573424, Accuracy: 68.0 %
# Class 0 F1 Score: 0.3333333333333333
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.888888888888889
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.8
# Class 7 F1 Score: 0.0
# Epoch 29, Train Loss: 0.8365784287452698, Validation Loss: 0.9188813300058246, Accuracy: 72.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.888888888888889
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.5
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.3333333333333333
# Epoch 30, Train Loss: 0.7612824589014053, Validation Loss: 0.9778683727420866, Accuracy: 72.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.5
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.28571428571428575
# Epoch 31, Train Loss: 1.0290332585573196, Validation Loss: 1.0033564950712026, Accuracy: 68.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.8571428571428571
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.5
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.28571428571428575
# Epoch 32, Train Loss: 1.687602385878563, Validation Loss: 0.9276065419707448, Accuracy: 64.0 %
# Class 0 F1 Score: 0.28571428571428575
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 0.5
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 33, Train Loss: 1.2222353518009186, Validation Loss: 0.9779141440894454, Accuracy: 56.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.25
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 34, Train Loss: 0.8906845301389694, Validation Loss: 0.8961739069991745, Accuracy: 64.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.6666666666666666
# Class 4 F1 Score: 0.3333333333333333
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.0
# Epoch 35, Train Loss: 0.8656095564365387, Validation Loss: 0.8767558232974261, Accuracy: 64.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.8571428571428571
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.0
# Epoch 36, Train Loss: 0.9092476069927216, Validation Loss: 0.9078078888962046, Accuracy: 64.0 %
# Class 0 F1 Score: 0.25
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 37, Train Loss: 1.2011928260326385, Validation Loss: 0.9525301881274209, Accuracy: 64.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.888888888888889
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.4444444444444445
# Class 7 F1 Score: 0.0
# Epoch 38, Train Loss: 0.6197412759065628, Validation Loss: 1.2128260888787918, Accuracy: 60.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.7272727272727273
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.28571428571428575
# Class 7 F1 Score: 0.0
# Epoch 39, Train Loss: 0.9558551758527756, Validation Loss: 1.179667928328272, Accuracy: 60.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.6
# Class 4 F1 Score: 0.4444444444444445
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 40, Train Loss: 0.7957996428012848, Validation Loss: 1.0994481466687285, Accuracy: 60.0 %
# Class 0 F1 Score: 0.5
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.5714285714285715
# Class 4 F1 Score: 0.28571428571428575
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 41, Train Loss: 1.364129677414894, Validation Loss: 1.0038313654228113, Accuracy: 60.0 %
# Class 0 F1 Score: 0.5714285714285715
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.4
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 42, Train Loss: 0.6269190758466721, Validation Loss: 1.242154182465747, Accuracy: 60.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.8333333333333333
# Class 3 F1 Score: 0.8571428571428571
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 43, Train Loss: 0.7492959946393967, Validation Loss: 1.1774100022763014, Accuracy: 64.0 %
# Class 0 F1 Score: 0.4
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.0
# Epoch 44, Train Loss: 0.615143895149231, Validation Loss: 1.108376351976767, Accuracy: 48.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.5
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 45, Train Loss: 0.6737188994884491, Validation Loss: 0.9772390314401127, Accuracy: 68.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 0.888888888888889
# Class 4 F1 Score: 0.6666666666666665
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.5
# Class 7 F1 Score: 0.4
# Epoch 46, Train Loss: 0.6755723059177399, Validation Loss: 0.9052057483477983, Accuracy: 80.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 0.9090909090909091
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.888888888888889
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.6666666666666666
# Epoch 47, Train Loss: 1.0524743050336838, Validation Loss: 0.9014230153532117, Accuracy: 76.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.8571428571428571
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 0.6666666666666666
# Class 7 F1 Score: 0.4
# Epoch 48, Train Loss: 0.6281846538186073, Validation Loss: 0.9764894843817455, Accuracy: 76.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 1.0
# Class 4 F1 Score: 0.7272727272727273
# Class 5 F1 Score: 0.6666666666666666
# Class 6 F1 Score: 1.0
# Class 7 F1 Score: 0.0
# Epoch 49, Train Loss: 0.6177874654531479, Validation Loss: 1.0579622103238944, Accuracy: 56.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.5714285714285715
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.4
# Epoch 50, Train Loss: 0.9896672368049622, Validation Loss: 1.007857659807196, Accuracy: 64.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.8571428571428571
# Class 2 F1 Score: 1.0
# Class 3 F1 Score: 0.5333333333333333
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 1.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.8571428571428571
# Training on fold 4/5
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# cuda
# Epoch 1, Train Loss: 1.9783461391925812, Validation Loss: 2.0860527658462527, Accuracy: 12.0 %
# Class 0 F1 Score: 0.14285714285714288
# Class 1 F1 Score: 0.25
# Class 2 F1 Score: 0.0
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0
# Epoch 2, Train Loss: 1.6616216450929642, Validation Loss: 2.090473380088806, Accuracy: 16.0 %
# Class 0 F1 Score: 0.0
# Class 1 F1 Score: 0.0
# Class 2 F1 Score: 0.2758620689655173
# Class 3 F1 Score: 0.0
# Class 4 F1 Score: 0.0
# Class 5 F1 Score: 0.0
# Class 6 F1 Score: 0.0
# Class 7 F1 Score: 0.0

# %%
import seaborn as sns

df = pd.read_csv(csv_filename)
df_long = df.melt(id_vars=['model_name', 'fold'], 
                  value_vars=all_labels_list,  # list all your label columns here
                  var_name='label', value_name='f1_score')
# Creating a boxplot for each label within each model
plt.figure(figsize=(12, 6))

# You might need to adjust the size of the figure based on the number of models and labels
sns.boxplot(x='label', y='f1_score', hue='model_name', data=df_long)

plt.title('F1 Score Distribution over Folds for Each Label and Model')
plt.xlabel('Label')
plt.ylabel('F1 Score')
plt.legend(title='Model Name')
plt.show()
